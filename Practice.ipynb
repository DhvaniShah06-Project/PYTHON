# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello From Dhvani!!")
# Out:
# Hello From Dhvani!!

# %%
print("Hello World Again !!!!!")
# Out:
# Hello World Again !!!!!
